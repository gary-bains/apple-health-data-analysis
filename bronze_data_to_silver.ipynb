# %%
import pandas as pd
import json

# %%
# Load the line sperated JSON into an Panada Data Frame

bronze_data = []

with open('bronze_data/records.jsonl', 'r', encoding='utf-8') as file:
    for line in file:
        strippedLine = line.strip()
        if strippedLine:
            bronze_data.append(json.loads(strippedLine))

bronze_df = pd.DataFrame(bronze_data)

bronze_df
# Out:
#                                                    type  \
# 0                      HKQuantityTypeIdentifierBodyMass
# 1                      HKQuantityTypeIdentifierBodyMass
# 2                      HKQuantityTypeIdentifierBodyMass
# 3                      HKQuantityTypeIdentifierBodyMass
# 4                      HKQuantityTypeIdentifierBodyMass
# ...                                                 ...
# 50845  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 50846  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 50847  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 50848  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 50849  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
#
#                    sourceName sourceVersion  \
# 0                    Withings       7010100
# 1                    Withings       7010100
# 2                    Withings       7010100
# 3                    Withings       7010100
# 4                    Withings       7010100
# ...                       ...           ...
# 50845  Gurpreet’s Apple Watch          11.2
# 50846  Gurpreet’s Apple Watch          11.2
# 50847  Gurpreet’s Apple Watch          11.2
# 50848  Gurpreet’s Apple Watch          11.2
# 50849  Gurpreet’s Apple Watch          11.2
#
#                                                   device unit  \
# 0      <<HKDevice: 0xdaa247d40>, name:Body+, manufact...   kg
# 1      <<HKDevice: 0xdaa247d40>, name:Body+, manufact...   kg
# 2      <<HKDevice: 0xdaa247d40>, name:Body+, manufact...   kg
# 3      <<HKDevice: 0xdaa247d40>, name:Body+, manufact...   kg
# 4      <<HKDevice: 0xdaa247d40>, name:Body+, manufact...   kg
# ...                                                  ...  ...
# 50845  <<HKDevice: 0xdac96f2f0>, name:Apple Watch, ma...   ms
# 50846  <<HKDevice: 0xdac96f2f0>, name:Apple Watch, ma...   ms
# 50847  <<HKDevice: 0xdac96f2f0>, name:Apple Watch, ma...   ms
# 50848  <<HKDevice: 0xdac96f2f0>, name:Apple Watch, ma...   ms
# 50849  <<HKDevice: 0xdac96f2f0>, name:Apple Watch, ma...   ms
#
#                     creationDate                  startDate  \
# 0      2025-01-01 10:09:48 -0600  2024-12-31 08:12:08 -0600
# 1      2025-01-01 10:09:48 -0600  2025-01-01 10:09:12 -0600
# 2      2025-01-01 12:38:05 -0600  2025-01-01 12:36:55 -0600
# 3      2025-01-02 08:14:29 -0600  2025-01-02 08:13:12 -0600
# 4      2025-01-03 07:34:06 -0600  2025-01-03 07:33:29 -0600
# ...                          ...                        ...
# 50845  2025-05-06 05:19:22 -0600  2025-05-06 05:18:21 -0600
# 50846  2025-05-06 09:42:09 -0600  2025-05-06 09:41:08 -0600
# 50847  2025-05-06 11:36:37 -0600  2025-05-06 11:35:35 -0600
# 50848  2025-05-06 15:20:20 -0600  2025-05-06 15:19:19 -0600
# 50849  2025-05-06 17:28:32 -0600  2025-05-06 17:27:30 -0600
#
#                          endDate    value
# 0      2024-12-31 08:12:08 -0600   73.473
# 1      2025-01-01 10:09:12 -0600   74.106
# 2      2025-01-01 12:36:55 -0600   73.707
# 3      2025-01-02 08:13:12 -0600   74.337
# 4      2025-01-03 07:33:29 -0600   74.293
# ...                          ...      ...
# 50845  2025-05-06 05:19:21 -0600  55.1371
# 50846  2025-05-06 09:42:08 -0600  50.3766
# 50847  2025-05-06 11:36:35 -0600  27.4739
# 50848  2025-05-06 15:20:13 -0600  18.6664
# 50849  2025-05-06 17:28:30 -0600  23.9112
#
# [50850 rows x 9 columns]

# %%
# Since we only need type 'type', 'unit', 'creationDate' and 'value'
# and don't care about 'sourceName', 'sourceVersion', 'device', 'startDate' and 'endDate' columns we can remove them

bronze_df_v2 = bronze_df[['type', 'unit', 'creationDate', 'value']]
bronze_df_v2
# Out:
#                                                    type unit  \
# 0                      HKQuantityTypeIdentifierBodyMass   kg
# 1                      HKQuantityTypeIdentifierBodyMass   kg
# 2                      HKQuantityTypeIdentifierBodyMass   kg
# 3                      HKQuantityTypeIdentifierBodyMass   kg
# 4                      HKQuantityTypeIdentifierBodyMass   kg
# ...                                                 ...  ...
# 50845  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 50846  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 50847  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 50848  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 50849  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
#
#                     creationDate    value
# 0      2025-01-01 10:09:48 -0600   73.473
# 1      2025-01-01 10:09:48 -0600   74.106
# 2      2025-01-01 12:38:05 -0600   73.707
# 3      2025-01-02 08:14:29 -0600   74.337
# 4      2025-01-03 07:34:06 -0600   74.293
# ...                          ...      ...
# 50845  2025-05-06 05:19:22 -0600  55.1371
# 50846  2025-05-06 09:42:09 -0600  50.3766
# 50847  2025-05-06 11:36:37 -0600  27.4739
# 50848  2025-05-06 15:20:20 -0600  18.6664
# 50849  2025-05-06 17:28:32 -0600  23.9112
#
# [50850 rows x 4 columns]

# %%
bronze_df_v2.iloc[0].unit
# Out:
# 'kg'

# %%
types = bronze_df_v2['type'].unique()
types
# Out:
# array(['HKQuantityTypeIdentifierBodyMass',
#        'HKQuantityTypeIdentifierHeartRate',
#        'HKQuantityTypeIdentifierBodyFatPercentage',
#        'HKQuantityTypeIdentifierLeanBodyMass',
#        'HKQuantityTypeIdentifierRestingHeartRate',
#        'HKQuantityTypeIdentifierWalkingHeartRateAverage',
#        'HKQuantityTypeIdentifierHeartRateVariabilitySDNN'], dtype=object)

# %%
for data_type in types:
    data_type_df = bronze_df_v2[bronze_df_v2['type'] == data_type]

    # only keeping the data / removing redundant info
    data_type_df_v2 = data_type_df[['creationDate', 'value']]

    data_type_name = data_type.replace('HKQuantityTypeIdentifier', '')
    new_col_name = f'{data_type_name} in {data_type_df.iloc[0].unit}'

    data_type_df_v3 = data_type_df_v2.rename(columns={'value': new_col_name})
    
    data_type_df_v3.to_csv(f'silver_data/{data_type_name}.csv', sep=',', index=False)
   
    data_type_df_v3.index = pd.to_datetime(data_type_df_v3['creationDate'])
    data_type_df_v3.drop(columns=['creationDate'], inplace=True)
    data_type_df_v3[new_col_name] = pd.to_numeric(data_type_df_v3[new_col_name])
    data_type_df_v3.plot.line()

    print(data_type_df_v3.head())
    print(data_type_df_v3.shape[0], 'rows')
    print()
# Out:
#                            BodyMass in kg
# creationDate
# 2025-01-01 10:09:48-06:00          73.473
# 2025-01-01 10:09:48-06:00          74.106
# 2025-01-01 12:38:05-06:00          73.707
# 2025-01-02 08:14:29-06:00          74.337
# 2025-01-03 07:34:06-06:00          74.293
# 167 rows
#
#                            HeartRate in count/min
# creationDate
# 2025-01-01 01:10:48-06:00                  65.000
# 2025-01-01 01:13:52-06:00                  75.451
# 2025-01-01 01:23:53-06:00                  74.000
# 2025-01-01 01:23:53-06:00                  73.000
# 2025-01-01 01:23:53-06:00                  72.000
# 48919 rows
#
#                            BodyFatPercentage in %
# creationDate
# 2025-01-01 10:09:48-06:00                 0.24689
# 2025-01-01 10:09:48-06:00                 0.24020
# 2025-01-01 12:38:05-06:00                 0.25900
# 2025-01-02 08:14:29-06:00                 0.24806
# 2025-01-03 07:34:06-06:00                 0.24175
# 134 rows
#
#                            LeanBodyMass in kg
# creationDate
# 2025-01-01 10:09:48-06:00              55.333
# 2025-01-01 10:09:48-06:00              56.306
# 2025-01-01 12:38:05-06:00              54.617
# 2025-01-02 08:14:29-06:00              55.897
# 2025-01-03 07:34:06-06:00              56.333
# 134 rows
#
#                            RestingHeartRate in count/min
# creationDate
# 2025-01-01 01:05:29-06:00                             76
# 2025-01-02 10:49:27-06:00                             71
# 2025-01-02 15:29:55-06:00                             64
# 2025-01-04 21:55:21-06:00                             66
# 2025-01-04 22:32:08-06:00                             72
# 122 rows
#
#                            WalkingHeartRateAverage in count/min
# creationDate
# 2025-01-01 01:05:29-06:00                                 116.0
# 2025-01-02 10:49:28-06:00                                 100.0
# 2025-01-02 16:47:10-06:00                                 107.0
# 2025-01-04 21:55:21-06:00                                 101.0
# 2025-01-04 22:14:21-06:00                                 122.0
# 124 rows
#
#                            HeartRateVariabilitySDNN in ms
# creationDate
# 2025-01-01 01:11:42-06:00                         73.4257
# 2025-01-01 02:53:36-06:00                        101.5740
# 2025-01-01 06:53:35-06:00                         39.5502
# 2025-01-01 08:53:33-06:00                         48.9004
# 2025-01-01 10:56:48-06:00                         43.4647
# 1250 rows
